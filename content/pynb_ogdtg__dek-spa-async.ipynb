# %% [markdown]
# <a href="https://colab.research.google.com/github/ogdtg/starter-code-ogdtg/blob/main/_work/03_Py_Notebooks/pynb_ogdtg@dek-spa-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Open Government Data, provided by **Canton Thurgau**
# *Autogenerated Python starter code for dataset with the identifier* **dek-spa-1**
#
# [Link to dataset on data.tg.ch](https://data.tg.ch/explore/dataset/dek-spa-1/information/)

# %% [markdown]
# ## Dataset
# # **Jugend+Sport: Teilnehmende, Leitpersonen und Gesamtauszahlungen**

# %% [markdown]
# ## Description
#
# <p>Dieser Datensatz beinhaltet Daten zum Sportförderprogramm Jugend + Sport im Kanton Thurgau, nämlich Teilnehmerzahlen, Anzahl Leitpersonen, sowie Gesamtauszahlungen innerhalb des Kantons. Aufgeführt sind die Daten jeweils pro Sportart und Jahr. Dieser Datensatz startet im Jahr 2017.</p><p></p><p>J+S ist das staatliche Förderungsprogramm der Schweiz für den Breitensport und den leistungsorientierten Nachwuchs. Zielgruppen des Programms sind Kinder zwischen 5 und 10 Jahren (Allround) und Jugendliche im Alter von 10 bis 20 Jahren. J+S bildet qualifizierte J+S-Leitende (meist ab 18 Jahren) aus, die in Sportorganisationen und im freiwilligen Schulsport Kinder und Jugendliche in ihrer Sportart unterrichten und Freude am Sport vermitteln.</p><p><br/></p><p>Weiterführende Informationen zu Jugend + Sport finden Sie hier:  <a href='https://www.jugendundsport.ch/' target='_blank'>https://www.jugendundsport.ch/</a></p><p></p><p>Datenquelle: Sportamt Kanton Thurgau</p>

# %% [markdown]
# ## Metadata
#
# - Issued                   :
# - Modified                 : 2023-11-06 11:22:56
# - Rights                   : CC BY 4.0
# - Keywords                 : Jugend + Sport, Auszahlungen J+S, Sportlager, Sportangebot, Teilnehmerzahlen, Sportart, Teilnehmer, Sport, Kinder

# %%
# %pip install -q requests pandas

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)
import requests
import pandas as pd
import json

# %%
import json
from IPython.display import JSON
from js import Object, fetch


# helper function for reading datasets with proper separator
async def get_dataset(dataset_id):
    url = f"https://data.tg.ch/api/explore/v2.0/catalog/datasets/{dataset_id}/exports/json"
    resp = await fetch(url,
      method="GET",
      credentials="same-origin"
    )
    res = await resp.text()
    data = JSON(json.loads(res))
    df = pd.DataFrame(data)
    return df

async def get_metadata(metadata, dataset_id):
    url = f'https://kantonthurgau.opendatasoft.com/api/explore/v2.0/catalog/datasets?select={metadata}&where=dataset_id%3D%22{dataset_id}%22&offset=0&timezone=UTC'
    headers = {'accept': 'application/json; charset=utf-8'}
    resp = await fetch(url,
      method="GET",
      credentials="same-origin",
      headers=headers
    )
    res = await resp.text()
    json_data = JSON(json.loads(res))
    extracted_metadata = json_data['datasets'][0]['dataset'][metadata]
    return extracted_metadata

# %% [markdown]
# ## Load data

# %%
# Read Data
dataset_id = 'dek-spa-1'

df = get_dataset(dataset_id)

df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 4
#       1 # Read Data
#       2 dataset_id = 'dek-spa-1'
# ----> 4 df = get_dataset(dataset_id)
#       6 df.head()
#
# Cell In[34], line 13, in get_dataset(dataset_id)
#       8 url = f"https://data.tg.ch/api/explore/v2.0/catalog/datasets/{dataset_id}/exports/json"
#       9 resp = fetch(url,
#      10   method="GET",
#      11   credentials="same-origin"
#      12 )
# ---> 13 res = resp.text()
#      14 data = JSON(json.loads(res))
#      15 df = pd.DataFrame(data)
#
# AttributeError: 'PyodideFuture' object has no attribute 'text'

# %%
# Dimensions of the Dataset
dimensions = df.shape
num_rows = dimensions[0]
num_cols = dimensions[1]

print("Number of rows (observations):", num_rows)
print("Number of columns (variables):", num_cols)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Dimensions of the Dataset
# ----> 2 dimensions = df.shape
#       3 num_rows = dimensions[0]
#       4 num_cols = dimensions[1]
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Explore Metadata

# %%
# Look at the fields
fields = get_metadata('fields',dataset_id)
fields_df = pd.DataFrame(fields)

fields_df
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Look at the fields
# ----> 2 fields = get_metadata('fields',dataset_id)
#       3 fields_df = pd.DataFrame(fields)
#       5 fields_df
#
# Cell In[16], line 12, in get_metadata(metadata, dataset_id)
#      10 url = f'https://kantonthurgau.opendatasoft.com/api/explore/v2.0/catalog/datasets?select={metadata}&where=dataset_id%3D%22{dataset_id}%22&offset=0&timezone=UTC'
#      11 headers = {'accept': 'application/json; charset=utf-8'}
# ---> 12 response = requests.get(url, headers=headers)
#      13 json_data = response.json()
#      14 extracted_metadata = json_data['datasets'][0]['dataset'][metadata]
#
# File /lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
# ...

# %%
# Keywords
keyword = get_metadata("keyword", dataset_id)

# Publisher
publisher = get_metadata("publisher", dataset_id)

print(f'Keywords: {keyword}')
print(f'Publisher: {publisher}')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[20], line 2
#       1 # Keywords
# ----> 2 keyword = get_metadata("keyword", dataset_id)
#       4 # Publisher
#       5 publisher = get_metadata("publisher", dataset_id)
#
# Cell In[16], line 12, in get_metadata(metadata, dataset_id)
#      10 url = f'https://kantonthurgau.opendatasoft.com/api/explore/v2.0/catalog/datasets?select={metadata}&where=dataset_id%3D%22{dataset_id}%22&offset=0&timezone=UTC'
#      11 headers = {'accept': 'application/json; charset=utf-8'}
# ---> 12 response = requests.get(url, headers=headers)
#      13 json_data = response.json()
#      14 extracted_metadata = json_data['datasets'][0]['dataset'][metadata]
#
# File /lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
# ...

# %% [markdown]
# ## Analyze data

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.info(memory_usage='deep', verbose=True)
#
# NameError: name 'df' is not defined

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")
# Out:
# No categorical data in dataset.

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")
# Out:
# No numercial data in dataset.

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 3
#       1 # check missing values with missingno
#       2 # https://github.com/ResidentMario/missingno
# ----> 3 import missingno as msno
#       4 msno.matrix(df, labels=True, sort='descending');
#
# ModuleNotFoundError: No module named 'missingno'

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")
# Out:
# No numercial data to plot.

# %%
# continue your code here...

# %% [markdown]
# ------------------------------------------------------------------------
#
# ## Questions about the data?
#
# Contact us via [Mail](mailto:ogd@tg.ch) or visit our [GitHub presence](https://github.com/ogdtg)
#
#
# ------------------------------------------------------------------------
#
# OGD-Koordinationsstelle Kanton Thurgau | Grabenstrasse 8 | 8510 Frauenfeld
